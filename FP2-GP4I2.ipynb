# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.24.1-py2.py3-none-any.whl (8.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 10.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy<2,>=1 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit) (1.24.3)
# Collecting altair<6,>=4.0
#   Downloading altair-5.0.1-py3-none-any.whl (471 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.5/471.5 kB 11.5 MB/s eta 0:00:0000:01
# Requirement already satisfied: cachetools<6,>=4.0 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit) (5.3.0)
# Collecting blinker<2,>=1.0.0
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Collecting pympler<2,>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging<24,>=14.1 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit) (21.3)
# Requirement already satisfied: click<9,>=7.0 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit) (8.0.4)
# Collecting rich<14,>=10.11.0
#   Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit) (6.1)
# Requirement already satisfied: toml<2 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: pillow<10,>=6.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit) (9.2.0)
# Requirement already satisfied: requests<3,>=2.4 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit) (2.28.1)
# Collecting validators<1,>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gitpython!=3.1.19,<4,>=3
#   Downloading GitPython-3.1.32-py3-none-any.whl (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit) (4.11.3)
# Requirement already satisfied: python-dateutil<3,>=2 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit) (2.8.2)
# Collecting pyarrow>=4.0
#   Downloading pyarrow-12.0.1-cp39-cp39-macosx_10_14_x86_64.whl (24.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.8/24.8 MB 8.9 MB/s eta 0:00:0000:01m00:01
# Collecting tzlocal<5,>=1.1
#   Downloading tzlocal-4.3.1-py3-none-any.whl (20 kB)
# Collecting pydeck<1,>=0.1.dev5
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 9.7 MB/s eta 0:00:00:00:010:01m
# Collecting protobuf<5,>=3.20
#   Downloading protobuf-4.23.4-cp37-abi3-macosx_10_9_universal2.whl (400 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.3/400.3 kB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5,>=4.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit) (4.3.0)
# Requirement already satisfied: tenacity<9,>=8.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit) (8.0.1)
# Requirement already satisfied: pandas<3,>=0.25 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit) (2.0.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (2.11.3)
# Requirement already satisfied: jsonschema>=3.0 in /opt/anaconda3/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (4.16.0)
# Requirement already satisfied: toolz in /opt/anaconda3/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (0.11.2)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from packaging<24,>=14.1->streamlit) (3.0.9)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas<3,>=0.25->streamlit) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas<3,>=0.25->streamlit) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil<3,>=2->streamlit) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.4->streamlit) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.4->streamlit) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.4->streamlit) (3.3)
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading Pygments-2.15.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.5 MB/s eta 0:00:00a 0:00:01
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 10.4 MB/s eta 0:00:00
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: decorator>=3.4.0 in /opt/anaconda3/lib/python3.9/site-packages (from validators<1,>=0.2->streamlit) (5.1.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.9/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.0.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (21.4.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19579 sha256=45a66673ae5775b4903e983ab35993acade52deeabf53a8b157ad68e68aec01a
#   Stored in directory: /Users/akshayodel/Library/Caches/pip/wheels/2d/f0/a8/1094fca7a7e5d0d12ff56e0c64675d72aa5cc81a5fc200e849
# Successfully built validators
# Installing collected packages: validators, smmap, pytz-deprecation-shim, pympler, pygments, pyarrow, protobuf, mdurl, blinker, tzlocal, pydeck, markdown-it-py, gitdb, rich, gitpython, altair, streamlit
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.11.2
#     Uninstalling Pygments-2.11.2:
#       Successfully uninstalled Pygments-2.11.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.3.3 requires pyqt5<5.16, which is not installed.
# spyder 5.3.3 requires pyqtwebengine<5.16, which is not installed.
# tensorflow 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.23.4 which is incompatible.
# tensorboard 2.11.2 requires protobuf<4,>=3.9.2, but you have protobuf 4.23.4 which is incompatible.
# Successfully installed altair-5.0.1 blinker-1.6.2 gitdb-4.0.10 gitpython-3.1.32 markdown-it-py-3.0.0 mdurl-0.1.2 protobuf-4.23.4 pyarrow-12.0.1 pydeck-0.8.1b0 pygments-2.15.1 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 rich-13.4.2 smmap-5.0.0 streamlit-1.24.1 tzlocal-4.3.1 validators-0.20.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.9/site-packages (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/anaconda3/lib/python3.9/site-packages (from requests) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests) (1.26.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from dateutil.relativedelta import relativedelta
from datetime import datetime

# API URL
api_url = "https://api.eia.gov/v2/international/data/?api_key=PYTvNry19FP8DgMdBAikT14IOtP21vBOZY2ZuDTJ&frequency=monthly&data[0]=value&facets[activityId][]=1&facets[productId][]=53&facets[countryRegionId][]=IND&facets[unit][]=TBPD&start=1990-01&end=2023-03&sort[0][column]=period&sort[0][direction]=asc&offset=0&length=5000"

# %%
import requests

# %%
#Read API data into a DataFrame
response = requests.get(api_url)
if response.status_code == 200:
    data = response.json()
    df = pd.DataFrame(data['response']['data'])
    df['ds'] = pd.to_datetime(df['period'])
    df['y'] = df['value']
    data_series = df[['ds', 'y']]

# %%
API_TOKEN = 'a122af78b08f7eccfe99605fe17fb2050d3116e1'

# Read CPI data from the specified URL
df_cpi = pd.read_csv(
    'https://www.econdb.com/api/series/CPIIN/?token=%s&format=csv' % API_TOKEN,
    parse_dates=['Date'])

# Merge the CPI dataframe and the data series dataframe
merged_df = df_cpi.merge(data_series, left_on='Date', right_on='ds', how='inner')

# Set the cutoff period for training
period = len(merged_df) - 6

# Select the training data
train_data = merged_df[['ds', 'CPIIN', 'y']][:period]

# Select the test data
test_data = merged_df[['ds', 'CPIIN', 'y']][period:]

# Define the ARIMA order
order = (1, 0, 0)

# Create and fit the ARIMAX model
model_arimax = ARIMA(train_data['y'], exog=train_data['CPIIN'], order=order)
model_arimax_fit = model_arimax.fit()

# %%
# Define the prediction function
def predict_oil_production(months_diff):
    # Predict CPIIN
    predicted_cpiin = model_fit.predict(start=len(data), end=len(data) + months_diff - 1)
    predicted_cpiin = pd.DataFrame(predicted_cpiin, columns=['CPIIN'])
    
    # Predict oil production using the trained ARIMAX model
    exog_reshaped = predicted_cpiin['CPIIN'].values.reshape(-1, 1)
    predicted_values = model_arimax_fit.predict(start=len(merged_df)-6, end=len(merged_df)-6 + months_diff - 1, exog=exog_reshaped)
    predicted_values = pd.DataFrame(predicted_values, columns=['Oil_Production'])
    
    # Generate monthly dates
    start_date = merged_df['ds'].dt.date.max() - relativedelta(months=5)
    end_date = datetime.today().date() + relativedelta(months=4)
    dates = pd.date_range(start=start_date, end=end_date, freq='MS')
    
    # Create a DataFrame with the predicted values and dates
    predicted_df = pd.DataFrame({'Month': dates})
    predicted_df = pd.concat([predicted_df, predicted_values], axis=1)
    
    return predicted_df

# Create Streamlit widgets
st.header('Oil Production Forecasting')

start_date = st.date_input('Select Test Start Date', value=merged_df['ds'].dt.date.max() - relativedelta(months=5))
end_date = st.date_input('Select Test End Date', value=datetime.today().date() + relativedelta(months=4))
button_predict = st.button('Predict')

# Define the main Streamlit app logic
if button_predict:
    date_diff = end_date - start_date
    months_diff = (end_date.year - start_date.year) * 12 + (end_date.month - start_date.month) + 1
    
    # Predict for the specified duration
    st.subheader('Oil Production Forecast: Custom Date')
    prediction_custom = predict_oil_production(months_diff)
    st.dataframe(prediction_custom)
    
    # Predict for the short-term duration (6 months)
    st.subheader('Oil Production Forecast: Short-Term Duration')
    prediction_short_term = predict_oil_production(6)
    st.dataframe(prediction_short_term)
    
    # Predict for the long-term duration (60 months)
    st.subheader('Oil Production Forecast: Long-Term Duration')
    prediction_long_term = predict_oil_production(60)
    st.dataframe(prediction_long_term)
    
    # Reset the end date
    end_date = start_date + relativedelta(days=date_diff.days)
    
    # Plot the oil production forecast
    st.subheader('Oil Production Forecast: Graph')
    plt.figure(figsize=(8, 4))
    plt.plot(prediction_custom['Month'], prediction_custom['Oil_Production'], label='Custom Date')
    plt.plot(prediction_short_term['Month'], prediction_short_term['Oil_Production'], label='Short-Term Duration')
    plt.plot(prediction_long_term['Month'], prediction_long_term['Oil_Production'], label='Long-Term Duration')
    plt.xlabel('Month')
    plt.ylabel('Oil Production')
    plt.title('Oil Production Forecast')
    plt.legend()
    st.pyplot(plt)
# Out:
# 2023-07-15 01:21:23.048
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /opt/anaconda3/lib/python3.9/site-packages/ipykernel_launcher.py [ARGUMENTS]
